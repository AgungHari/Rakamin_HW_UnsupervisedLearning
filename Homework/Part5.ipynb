# %% [markdown]
# ## 4. Interpretasi cluster yang dihasilkan secara bisnis dan berikan<br>rekomendasi yang sesuai dengan cluster yang dihasilkan<br>(30 poin)
#
# <br>Langkah-langkah:
# <br>a. Tempelkan kembali label yang dihasilkan ke dataframe asal, dan keluarkan statistik
# ﬁtur dari setiap cluster
# <br>b. Deskripsikan secara kontekstual customer seperti apa yang ada di masing-masing
# cluster
# <br>c. Berdasarkan cluster tersebut, berikan 1-2 rekomendasi bisnis
#
#
# <br>Untuk mempermudah kamu, yuk lihat resource di bawah ini:
# - Topic Unsupervised Learning - Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#k means dan elbow method
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
data_std = pd.read_csv(r'D:\Rakamin_UnsupervisedLearning\Homework\flight_Versi4_Mateng.csv')

# %%
data = pd.read_csv(r'D:\Rakamin_UnsupervisedLearning\Homework\flight_Versi4_NoOutlier.csv')

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(data_std)

# %%
df_data_std = pd.DataFrame(data=data_std, columns=list(data))

# %%
df_data_std['clusters'] = kmeans.labels_
data['clusters'] = kmeans.labels_

# %%
data.head(3)
# Out:
#    SUM_YR_1_Log_Z  avg_discount_Z  Points_Sum_Log_Z  clusters
# 0        1.533794        1.359654          2.975882         1
# 1        1.500886        1.343528          2.985297         1
# 2        1.523211        1.330771          2.882413         1

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(data_std)
    inertia.append(kmeans.inertia_)



plt.figure(figsize=(20, 10))
# plt.plot(inertia)

sns.lineplot(x=range(2, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(2, 11), y=inertia, s=300, color='#800000',  linestyle='--')
# Out:
# <Axes: >

# %%
range_n_clusters = list(range(2,11))
print(range_n_clusters)
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['avg_discount_Z'][data.clusters == 0], 
           data['SUM_YR_1_Log_Z'][data.clusters == 0], 
           data['Points_Sum_Log_Z'][data.clusters == 0], 
           c='blue', s=6, edgecolor='green', linestyle='--')
ax.scatter(data['avg_discount_Z'][data.clusters == 1], 
           data['SUM_YR_1_Log_Z'][data.clusters == 1], 
           data['Points_Sum_Log_Z'][data.clusters == 1], 
           c='red', s=6, edgecolor='green', linestyle='--')
ax.scatter(data['avg_discount_Z'][data.clusters == 2], 
           data['SUM_YR_1_Log_Z'][data.clusters == 2], 
           data['Points_Sum_Log_Z'][data.clusters == 2], 
           c='green', s=6, edgecolor='green', linestyle='--')

plt.xlabel("AVG_INTERVAL_Log_Z")
plt.ylabel("Sum Year 1 Log Z")
ax.set_zlabel('Last to End Log Z')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# === 1) subsample biar ringan ===
np.random.seed(0)
show = min(len(data), 8000)   # tampilkan 8k titik saja
idx = np.random.choice(data.index, size=show, replace=False)
d = data.loc[idx]

# === 2) plot 3D dengan marker kecil & transparansi ===
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

for c in sorted(d['clusters'].unique()):
    m = d['clusters'] == c
    ax.scatter(
        d.loc[m, 'avg_discount_Z'],
        d.loc[m, 'SUM_YR_1_Log_Z'],
        d.loc[m, 'Points_Sum_Log_Z'],
        s=6, alpha=0.25, linewidths=0  # kuncinya di sini
    )

ax.set_xlabel('avg_discount_Z')
ax.set_ylabel('SUM_YR_1_Log_Z')
ax.set_zlabel('Points_Sum_Log_Z')
ax.view_init(elev=20, azim=35)  # sudut pandang lebih “lapang”
plt.title('K-Means Clusters (3D, subsample + alpha)')
plt.show()

# %%
# plot 3d dengan skala asli EXPM1
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
for c in sorted(data['clusters'].unique()):
    m = data['clusters'] == c
    ax.scatter(
        data.loc[m, 'avg_discount_Z'],
        data.loc[m, 'SUM_YR_1_Log_Z'],
        data.loc[m, 'Points_Sum_Log_Z'],
        s=6, alpha=0.25, linewidths=0  # kuncinya di sini
    )
ax.set_xlabel('avg_discount_Z')
ax.set_ylabel('SUM_YR_1_Log_Z')
ax.set_zlabel('Points_Sum_Log_Z')
ax.view_init(elev=20, azim=35)  # sudut pandang lebih “lapang”
plt.title('K-Means Clusters (3D, skala asli)')
plt.show()

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components=2)

pca.fit(data_std)
pcs = pca.transform(data_std)

data_pca = pd.DataFrame(data = pcs, columns = ['PC 1', 'PC 2'])
data_pca['clusters'] = data['clusters']
data_pca.head()
# Out:
#        PC 1      PC 2  clusters
# 0  4.500642  0.162834         1
# 1  4.476576  0.141149         1
# 2  4.331000  0.183405         1
# 3  2.706415  1.422590         1
# 4  4.491652 -0.166295         1

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.scatterplot(
    x="PC 1", y="PC 2",
    hue="clusters",
    data=data_pca.sample(n=5000, random_state=42),  # subsample biar ringan
    palette=['blue','red','green'],
    s=15, alpha=0.4,   # marker kecil + transparan
    ax=ax
)

plt.title("K-Means Clusters (PCA 2D)", fontsize=16)
plt.show()
